# %%
# !pip install easyocr

# %%
import matplotlib.pyplot as plt
import cv2
import easyocr

from IPython.display import Image

# %%
reader = easyocr.Reader(['en'])

# %%
image1 = Image('Image1.jpg')

# %%
image1

# %%
text_from_image1 = reader.readtext('Image1.jpg')

# %%
extracted_text_from_image1 = [letter[1] for letter in text_from_image1]

# %%
extracted_text_from_image1
# Out:
# ['LIFE IS LIKE RIDIIG A',
#  'Text Properties',
#  'BICVCLE.',
#  'YOUR',
#  'TO KEEP',
#  'sans',
#  'Opeln',
#  'BALANCE VOU MMUST',
#  'GDax',
#  'KEEP MOVIING.',
#  'Background',
#  'AlBERT EINSTEIN',
#  'autline',
#  'Hignlignt',
#  'Options']

# %%
image2 = Image('Image2.jpg')

# %%
image2

# %%
text_from_image2 = reader.readtext('Image2.jpg')

# %%
extracted_text_from_image2 = [letter[1] for letter in text_from_image2]

# %%
extracted_text_from_image2
# Out:
# ['Gallery',
#  'Gallery',
#  'E',
#  'WEI',
#  'OUI',
#  'THE',
#  'T@',
#  'tMGLE',
#  'Import Feni:',
#  'a_31',
#  'Cne',
#  'Font',
#  'style',
#  'Deslgn',
#  'attributes',
#  'EJil Style',
#  'fesasnizi',
#  '001050111',
#  '250.051',
#  'ksl4i',
#  'M-jsaonii eakl',
#  'delete',
#  '[=00=0417274111^12',
#  'Guza0',
#  'nre',
#  '76117117=51-]11!181',
#  'ezdo',
#  'Buu pTbL HEh[',
#  'Trarlang',
#  'rDns',
#  'Ft nIAll',
#  'czaslaca',
#  'Fi=nl',
#  'ahal72',
#  '=#e74',
#  'zallLaava',
#  '15_6154',
#  'alilt',
#  'zralnanLkie1',
#  '25470"',
#  '=11571',
#  '7a arpja',
#  'zl2s',
#  '.723',
#  '5ki=']
